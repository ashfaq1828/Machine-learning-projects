# %% [markdown]
# ## Performa exploratory data analysis on the given datasets (electric_motor.csv)
#
#
# ## Find and plot all the time series, histograms, violin plot, see distribution of data sets, cross-correlation of the data. Also, analyze other plots taught in EDA lecture

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pmsm_temperature_data(1).csv')

# %%
df
# Out:
#          ambient   coolant       u_d       u_q  motor_speed    torque  \
# 0      -0.752143 -1.118446  0.327935 -1.297858    -1.222428 -0.250182
# 1      -0.771263 -1.117021  0.329665 -1.297686    -1.222429 -0.249133
# 2      -0.782892 -1.116681  0.332771 -1.301822    -1.222428 -0.249431
# 3      -0.780935 -1.116764  0.333700 -1.301852    -1.222430 -0.248636
# 4      -0.774043 -1.116775  0.335206 -1.303118    -1.222429 -0.248701
# ...          ...       ...       ...       ...          ...       ...
# 998065 -0.047497  0.341638  0.331475 -1.246114    -1.222428 -0.255640
# 998066 -0.048839  0.320022  0.331701 -1.250655    -1.222437 -0.255640
# 998067 -0.042350  0.307415  0.330946 -1.246852    -1.222430 -0.255640
# 998068 -0.039433  0.302082  0.330987 -1.249505    -1.222432 -0.255640
# 998069 -0.043803  0.312666  0.330830 -1.246590    -1.222431 -0.255640
#
#              i_d       i_q        pm  stator_yoke  stator_tooth  \
# ...

# %%
df.describe()
# Out:
#              ambient        coolant            u_d            u_q  \
# count  998070.000000  998070.000000  998070.000000  998070.000000
# mean       -0.003905       0.004723       0.004780      -0.005690
# std         0.993127       1.002423       0.997878       1.002330
# min        -8.573954      -1.429349      -1.655373      -1.861463
# 25%        -0.599385      -1.037925      -0.826359      -0.927390
# 50%         0.266157      -0.177187       0.267542      -0.099818
# 75%         0.686675       0.650709       0.358491       0.852625
# max         2.967117       2.649032       2.274734       1.793498
#
#          motor_speed         torque            i_d            i_q  \
# count  998070.000000  998070.000000  998070.000000  998070.000000
# mean       -0.006336      -0.003333       0.006043      -0.003194
# std         1.001229       0.997907       0.998994       0.997912
# min        -1.371529      -3.345953      -3.245874      -3.341639
# ...

# %%
df.isnull().sum()
# Out:
# ambient           0
# coolant           0
# u_d               0
# u_q               0
# motor_speed       0
# torque            0
# i_d               0
# i_q               0
# pm                0
# stator_yoke       0
# stator_tooth      0
# stator_winding    0
# profile_id        0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Histogram

# %%
sns.histplot(data=df, x="ambient",kde=True)
# Out:
# <AxesSubplot:xlabel='ambient', ylabel='Count'>

# %%
sns.histplot(data=df, x="u_d",kde=True)
# Out:
# <AxesSubplot:xlabel='u_d', ylabel='Count'>

# %%
sns.histplot(data=df, x="u_q",kde=True)
# Out:
# <AxesSubplot:xlabel='u_q', ylabel='Count'>

# %%
sns.histplot(data=df, x="i_d",kde=True)
# Out:
# <AxesSubplot:xlabel='i_d', ylabel='Count'>

# %%
sns.histplot(data=df, x="i_q",kde=True)
# Out:
# <AxesSubplot:xlabel='i_q', ylabel='Count'>

# %%
sns.histplot(data=df, x="motor_speed",kde=True)
# Out:
# <AxesSubplot:xlabel='motor_speed', ylabel='Count'>

# %%
sns.histplot(data=df, x="coolant",kde=True)
# Out:
# <AxesSubplot:xlabel='coolant', ylabel='Count'>

# %%
sns.histplot(data=df, x="pm",kde=True)
# Out:
# <AxesSubplot:xlabel='pm', ylabel='Count'>

# %%
sns.histplot(data=df, x="profile_id",kde=True)
# Out:
# <AxesSubplot:xlabel='profile_id', ylabel='Count'>

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(x=df["ambient"])
# Out:
# <AxesSubplot:xlabel='ambient'>

# %%
sns.violinplot(x=df["coolant"])
# Out:
# <AxesSubplot:xlabel='coolant'>

# %%
sns.violinplot(x=df["u_d"])
# Out:
# <AxesSubplot:xlabel='u_d'>

# %%
sns.violinplot(x=df["u_q"])
# Out:
# <AxesSubplot:xlabel='u_q'>

# %%
sns.violinplot(x=df["i_d"])
# Out:
# <AxesSubplot:xlabel='i_d'>

# %%
sns.violinplot(x=df["i_q"])
# Out:
# <AxesSubplot:xlabel='i_q'>

# %%
sns.violinplot(x=df["stator_yoke"])
# Out:
# <AxesSubplot:xlabel='stator_yoke'>

# %%
sns.violinplot(x=df["stator_tooth"])
# Out:
# <AxesSubplot:xlabel='stator_tooth'>

# %%
sns.violinplot(x=df["pm"])
# Out:
# <AxesSubplot:xlabel='pm'>

# %%
sns.violinplot(x=df["profile_id"])
# Out:
# <AxesSubplot:xlabel='profile_id'>

# %% [markdown]
# # Box plot

# %%
sns.boxplot(x=df["ambient"])
# Out:
# <AxesSubplot:xlabel='ambient'>

# %%
sns.boxplot(x=df["coolant"])
# Out:
# <AxesSubplot:xlabel='coolant'>

# %%
sns.boxplot(x=df["u_d"])
# Out:
# <AxesSubplot:xlabel='u_d'>

# %%
sns.boxplot(x=df["u_q"])
# Out:
# <AxesSubplot:xlabel='u_q'>

# %%
sns.boxplot(x=df["motor_speed"])
# Out:
# <AxesSubplot:xlabel='motor_speed'>

# %%
sns.boxplot(x=df["torque"])
# Out:
# <AxesSubplot:xlabel='torque'>

# %%
sns.boxplot(x=df["i_d"])
# Out:
# <AxesSubplot:xlabel='i_d'>

# %%
sns.boxplot(x=df["i_q"])
# Out:
# <AxesSubplot:xlabel='i_q'>

# %%
sns.boxplot(x=df["pm"])
# Out:
# <AxesSubplot:xlabel='pm'>

# %%
sns.boxplot(x=df["stator_yoke"])
# Out:
# <AxesSubplot:xlabel='stator_yoke'>

# %%
sns.boxplot(x=df["stator_tooth"])
# Out:
# <AxesSubplot:xlabel='stator_tooth'>

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df.sample(500))

# %% [markdown]
# # Co-relation

# %%
corr=df.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True,cmap='mako')
# Out:
# <AxesSubplot:>
